# %% [markdown]
# # Beginner Data Cleaning | Analysis | Visualization | Feature Engineering | Preprocessing | Model Evaluation
#
# 1. import & setup
# 2. load dataset's
# 3. basic Exploration
# 4. Data Cleaning
# 5. EDA
# 6. Correlation Analysis
# 7. Feature Engineering for ML
# 8. train_test_split
# 9. model evaluation

# %% [markdown]
# ## Impots & Setup

# %%
#Core
import pandas as pd
import numpy as np

#visualization
import seaborn as sns
import matplotlib.pyplot as plt

#ML
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

#settings
pd.set_option('display.max_column', None)
sns.set(style= "whitegrid")

#handle warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Dataset's

# %%
#load dataset's with 1k row and 5 columns
df= pd.read_csv('/kaggle/input/datasets/shaistashahid/freelancer-income-vs-skills/freelancer_earnings - freelancer_earnings_vs_skillstack_dataset.csv')

# df = df.sample(n=min(1000, len(df)), random_state=42)

df = df[['category', 'primary_skills', 'years_experience', 'hourly_rate_usd', 'annual_income_usd']]

df.head(5)
# Out:
#               category                             primary_skills  \
# 0    AI/ML Engineering  Computer Vision, TensorFlow, Data Science
# 1  Backend Development                              PHP, Ruby, Go
# 2         UI/UX Design              Sketch, Wireframing, Adobe XD
# 3               DevOps                 Kubernetes, Terraform, AWS
# 4               DevOps                  Azure, Docker, Kubernetes
#
#    years_experience  hourly_rate_usd annual_income_usd
# 0               1.6            66.41        $58,873.61
# 1               8.3           112.79       $108,183.05
# 2               3.6            94.21        $88,681.22
# 3               2.3           118.87       $109,229.42
# 4               8.8            82.76        $66,298.22

# %% [markdown]
# ## 3. Basic Exploration

# %%
df.shape
# Out:
# (500, 5)

# %%
df.tail(5)
# Out:
#               category                                  primary_skills  \
# 495       UI/UX Design                         Adobe XD, Sketch, Figma
# 496      Cybersecurity  Network Security, Security Audit, Cryptography
# 497             DevOps                   Docker, Kubernetes, Terraform
# 498  AI/ML Engineering                            Python, NLP, PyTorch
# 499         Blockchain             Ethereum, Solidity, Smart Contracts
#
#      years_experience  hourly_rate_usd annual_income_usd
# 495               9.7           129.08       $114,149.16
# 496               1.2            84.37        $86,158.21
# 497               6.4           220.15       $225,178.75
# 498               7.4           220.01       $236,868.46
# 499              10.8           127.68       $136,126.59

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   category           500 non-null    object
#  1   primary_skills     500 non-null    object
#  2   years_experience   500 non-null    float64
#  3   hourly_rate_usd    500 non-null    float64
#  4   annual_income_usd  500 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 19.7+ KB

# %%
df.describe()
# Out:
#        years_experience  hourly_rate_usd
# count        500.000000       500.000000
# mean           5.850000        97.149820
# std            2.934779        52.697831
# min            0.500000        17.280000
# 25%            3.600000        55.182500
# 50%            5.600000        84.445000
# 75%            7.800000       130.497500
# max           14.000000       281.470000

# %%
print('Check The Null Value:-')
print(df.isnull().sum())
# Out:
# Check The Null Value:-
# category             0
# primary_skills       0
# years_experience     0
# hourly_rate_usd      0
# annual_income_usd    0
# dtype: int64

# %%
print('Check the duplicated value:')
print(df.duplicated().sum())
# Out:
# Check the duplicated value:
# 0
