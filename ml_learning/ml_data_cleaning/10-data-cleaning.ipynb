# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here are several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/masumauch/worldcity/world.csv

# %%
df = pd.read_csv("/kaggle/input/datasets/masumauch/worldcity/world.csv", on_bad_lines='skip')

# %%
# df = pd.read_csv("/kaggle/input/datasets/masumauch/worldcity/world.csv", sep=';')

# %% [markdown]
# ## Data Analysis

# %%
df
# Out:
#        ID            Name CountryCode       District  Population
# 0       1           Kabul         AFG          Kabol   1780000.0
# 1       2        Qandahar         AFG       Qandahar    237500.0
# 2       3           Herat         AFG          Herat    186800.0
# 3       4  Mazar-e-Sharif         AFG          Balkh    127800.0
# 4       5       Amsterdam         NLD  Noord-Holland    731200.0
# ...   ...             ...         ...            ...         ...
# 5059  ZMB          Tongan           F           11.0         NaN
# 5060  ZWE         English           T            2.2         NaN
# 5061  ZWE         Ndebele           F           16.2         NaN
# 5062  ZWE          Nyanja           F            2.2         NaN
# 5063  ZWE           Shona           F           72.1         NaN
#
# [5064 rows x 5 columns]

# %%
df.sample(5)
# Out:
#         ID             Name CountryCode          District  Population
# 1223  1224  Kollam (Quilon)         IND            Kerala    139852.0
# 1430  1431          Mahabad         IRN  West Azerbaidzan    107799.0
# 2334  2335           Taejon         KOR            Taejon   1425835.0
# 1270  1271         Cuddapah         IND    Andhra Pradesh    121463.0
# 3489  3490        Kecskemét         HUN       Bács-Kiskun    105606.0

# %%
df.tail(5)
# Out:
#        ID     Name CountryCode District  Population
# 5059  ZMB   Tongan           F     11.0         NaN
# 5060  ZWE  English           T      2.2         NaN
# 5061  ZWE  Ndebele           F     16.2         NaN
# 5062  ZWE   Nyanja           F      2.2         NaN
# 5063  ZWE    Shona           F     72.1         NaN

# %%
df.shape
# Out:
# (5064, 5)

# %%
print("Check In Duplicated Row's")
print(df.duplicated().sum())
# Out:
# Check In Duplicated Row's
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5064 entries, 0 to 5063
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           5064 non-null   object
#  1   Name         5064 non-null   object
#  2   CountryCode  5064 non-null   object
#  3   District     5060 non-null   object
#  4   Population   4079 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 197.9+ KB

# %%
# df.isna().sum()[df.isna().sum()> 0]
print('Null Value of City:-')
print(df.isna().sum())
# Out:
# Null Value of City:-
# ID               0
# Name             0
# CountryCode      0
# District         4
# Population     985
# dtype: int64

# %%
#describe with population
print('Data Understanding In Population')
df['Population'].describe()
# Out:
# Data Understanding In Population
# count    4.079000e+03
# mean     3.504682e+05
# std      7.237757e+05
# min      4.200000e+01
# 25%      1.147890e+05
# 50%      1.670510e+05
# 75%      3.106385e+05
# max      1.050000e+07
# Name: Population, dtype: float64

# %%
df.groupby('District')['Population'].sum().sort_values(ascending=False)
# Out:
# District
# São Paulo      26316966.0
# Maharashtra    23659433.0
# England        19978543.0
# Punjab         19708438.0
# California     16716706.0
#                   ...
# 2.6                   0.0
# 2.7                   0.0
# 2.8                   0.0
# 2.9                   0.0
# 91.5                  0.0
# Name: Population, Length: 1724, dtype: float64

# %%
df['CountryCode'].value_counts()
# Out:
# CountryCode
# F             746
# CHN           363
# IND           341
# USA           274
# BRA           250
#              ...
# WLF             1
# VAT             1
# VUT             1
# VIR             1
# IsOfficial      1
# Name: count, Length: 235, dtype: int64

# %%
df.groupby('CountryCode')['Population'].sum().sort_values(ascending=False)
# Out:
# CountryCode
# CHN           175953614.0
# IND           123298526.0
# BRA            85876862.0
# USA            78625774.0
# JPN            77965107.0
#                  ...
# TKL                 300.0
# PCN                  42.0
# F                     0.0
# IsOfficial            0.0
# T                     0.0
# Name: Population, Length: 235, dtype: float64

# %% [markdown]
# ## EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
country_summary = df.groupby('CountryCode')['Population'].agg(
    ['count', 'sum', 'mean', 'median', 'min', 'max']
).sort_values('sum', ascending=False)

country_summary.head(10)
# Out:
#              count          sum           mean    median      min         max
# CountryCode
# CHN            363  175953614.0  484720.699725  195064.0  89288.0   9696300.0
# IND            341  123298526.0  361579.255132  157358.0  89053.0  10500000.0
# BRA            250   85876862.0  343507.448000  171177.0  89200.0   9968485.0
# USA            274   78625774.0  286955.379562  149794.0  89063.0   8008278.0
# JPN            248   77965107.0  314375.431452  167123.5  91170.0   7980230.0
# RUS            189   69150700.0  365876.719577  194100.0  89800.0   8389200.0
# MEX            173   59752521.0  345390.294798  172410.0  89143.0   8591309.0
# KOR             70   38999893.0  557141.328571  231794.0  92239.0   9981619.0
# IDN             85   37485695.0  441008.176471  145000.0  89900.0   9604900.0
# PAK             59   31546745.0  534690.593220  151000.0  89400.0   9269265.0

# %%
# Calculate population rates by countrycode
country_mean= df.groupby('CountryCode')['Population'].mean()
print("Population rate by CountryCode:")
print(country_mean)
print("\n")

# Plot population rates by countrycode
country_mean.head(10).plot(kind='bar')
plt.title("Top 10 Countries by Total Population")
plt.ylabel("Total Population")
plt.show()
# Out:
# Population rate by CountryCode:
# CountryCode
# ABW     29034.000000
# AFG    583025.000000
# AGO    512320.000000
# AIA       778.000000
# ALB    270000.000000
#            ...
# YEM    290616.666667
# YUG    273688.375000
# ZAF    345372.045455
# ZMB    353357.142857
# ZWE    455070.000000
# Name: Population, Length: 235, dtype: float64

# %%
country_mean.head(10).plot(kind='bar', logy=True)
plt.show()

# %%
df['Population'].hist(bins=50)
plt.xlabel("Population")
plt.ylabel("Frequency")
plt.title("Population Distribution")
plt.show()

# %%
# Log Distribution

df['LogPopulation'] = np.log1p(df['Population'])
df['LogPopulation'].hist(bins=50)
plt.title("Log Population Distribution")
plt.show()
