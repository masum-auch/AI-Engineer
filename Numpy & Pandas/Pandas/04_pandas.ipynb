# %% [markdown]
# <a href="https://colab.research.google.com/github/masum-auch/AI-Engineer/blob/main/Numpy%20%26%20Pandas/Pandas/04_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Series Maths Methods | Pandas | part 3

# %%
import numpy as pd
import pandas as pd

# %%
subs = pd.read_csv('/content/subs.csv')

# %%
subs = subs.iloc[:, 0]

# %%
type(subs)
# Out:
# pandas.core.series.Series

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk= pd.read_csv('/content/kohli_ipl.csv')
vk= vk.iloc[:, 0]

# %%
vk
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 210    211
# 211    212
# 212    213
# 213    214
# 214    215
# Name: match_no, Length: 215, dtype: int64

# %%
vk.count()
# Out:
# np.int64(215)

# %%
vk.mean()
# Out:
# np.float64(108.0)

# %%
vk.sort_values()
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 210    211
# 211    212
# 212    213
# 213    214
# 214    215
# Name: match_no, Length: 215, dtype: int64

# %%
# sum -> product
subs.sum()
# Out:
# np.int64(49510)

# %%
movies= pd.read_csv('/content/bollywood.csv', )
movies= movies.iloc[:, 0]

# %%
# mean -> median -> mode -> std -> var
subs.mean()
print(vk.median())
print(movies.mode())
print(subs.std())
print(vk.var())
# Out:
# 108.0
# 0                     Andaaz
# 1             Gabbar Is Back
# 2    Tanu Weds Manu: Returns
# Name: movie, dtype: object
# 62.67502303725269
# 3870.0

# %%
# min/max
subs.max()
# Out:
# 396

# %%
# describe
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64
