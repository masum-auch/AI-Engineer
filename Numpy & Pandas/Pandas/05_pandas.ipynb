# %% [markdown]
# <a href="https://colab.research.google.com/github/masum-auch/AI-Engineer/blob/main/Numpy%20%26%20Pandas/Pandas/05_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Masum")
# Out:
# Masum

# %% [markdown]
# # Learn Pandas libraries | Series Maths Methods | Indexing

# %%
import numpy as pd

# %%
#import pandas libraries
import pandas as pd

# %%
#load data
subs= pd.read_csv('/content/subs.csv')
subs = subs.iloc[:, 0]

# %%
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
type(subs)
# Out:
# pandas.core.series.Series

# %%
vk= pd.read_csv('/content/kohli_ipl.csv')
vk= vk.iloc[:, 0]

# %%
vk.head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: match_no, dtype: int64

# %%
type(vk)
# Out:
# pandas.core.series.Series

# %%
movie= pd.read_csv('/content/bollywood.csv')
movie= movie.iloc[:, 0]

# %%
type(movie)
# Out:
# pandas.core.series.Series

# %%
movie.head()
# Out:
# 0                Uri: The Surgical Strike
# 1                           Battalion 609
# 2    The Accidental Prime Minister (film)
# 3                         Why Cheat India
# 4                         Evening Shadows
# Name: movie, dtype: object

# %%
#count
print(vk.count())
# Out:
# match_no    215
# runs        215
# dtype: int64

# %%
# sum -> product
subs.sum()
# Out:
# Subscribers gained    49510
# dtype: int64

# %%
# mean -> median -> mode -> std -> var
subs.mean()
print(vk.median())
print('\n')
print(movie.mode())
print('\n')
print(subs.std())
print(vk.var())
# Out:
# 108.0
#
#
# 0                     Andaaz
# 1             Gabbar Is Back
# 2    Tanu Weds Manu: Returns
# Name: movie, dtype: object
#
#
# 62.67502303725269
# 3870.0

# %%
# min/max
subs.max()
# Out:
# 396

# %%
# describe
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# #

# %% [markdown]
# ## Series Indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64
